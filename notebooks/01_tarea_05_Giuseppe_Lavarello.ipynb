# %% [markdown]
# <div>
# <img src="https://i.ibb.co/v3CvVz9/udd-short.png" width="150"/>
#     <br>
#     <strong>Universidad del Desarrollo</strong><br>
#     <em>Magíster en Data Science</em><br>
#     <em>Profesor: Víctor Navarro Aránguiz</em><br>
#
# </div>
#
# # Python para Data Science: Tarea 05
# *16 de Julio de 2024*
#
# **Fecha de Entrega**: 21 de Julio de 2024
#
# **Objetivos:**
#   - Familiarizarse con el manejo de versiones a través de Git.
#
# **Puntaje Total:** 12 Puntos
#
# **Nombre Estudiante(s)**: `Giuseppe Lavarello`

# %% [markdown]
# ## 1 Inicialización
#
# - Utilice pandas para leer el siguiente csv:
#     - https://raw.githubusercontent.com/plotly/datasets/master/iris-data.csv
#
# - Muestre inicialmente el tamaño (shape) del DataFrame creado, junto a las primeras 5 columnas. Realice
# los commits que considere pertinentes.

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/iris-data.csv")
print(f"El dataset tiene {df.shape[1]} columnas y {df.shape[0]} filas.")
print("Las primeras 5 filas son:")
df.head(5)
# Out:
# El dataset tiene 5 columnas y 150 filas.
# Las primeras 5 filas son:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## 2 Dentro del mismo notebook, describa (utilizando código y markdown):
#
# <ol type="a">
# <li>Qué columnas tiene el dataset y que representan.</li>
# <li>La existencia (o no) de valores nulos.</li>
# <li>Estadísticas de cada columna numérica (utilice df.describe()).</li>
# <li>Cuántas filas existen para cada clase de flor.</li>
# </ol>

# %% [markdown]
# ### a) Qué columnas tiene el dataset y que representan.
#
# - Las columnas presentes son "sepal length", "sepal width", "petal length", "petal width", y "class".
#     - o en español largo del sepalo, ancho del sepalo, largo del petalo, ancho del petalo, y clase.
#
# - Las primeras cuatro features, son numericas continuas con medida en centimetros y reprecentan el largo y ancho de cada parte indicada de la flor (petalo o sepalo segun sea el caso), mientras que la ultima feature es del tipo categorico y representa el tipo de una planta de iris.

# %%
print(list(df.columns))
print(df.dtypes)
# Out:
# ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']
# sepal length    float64
# sepal width     float64
# petal length    float64
# petal width     float64
# class            object
# dtype: object

# %% [markdown]
# ### b) La existencia (o no) de valores nulos.
#
# - No existen valores nulos en la tabla, lo podemos observar en los siguientes graficos:

# %%
import missingno as msng
msng.matrix(df)
# Out:
# <Axes: >

# %%
msng.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# ### c) Estadísticas de cada columna numérica (utilice df.describe()).
#
# - Para la feature "sepal length":
#     - Posee **150** instancias
#     - Tiene un promedio de **5.84** cm de largo
#     - Una desviación estándar de **0.83** cm
#     - El sépalo de largo menor es de **4.30** cm de largo
#     - El sépalo de largo mayor es de **7.90** cm de largo
#     - Su media es de **5.80** cm de largo

# %%
df["sepal length"].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal length, dtype: float64

# %% [markdown]
# ---
# - Para la feature "sepal width":
#     - Posee **150** instancias
#     - Tiene un promedio de **3.05** cm de ancho
#     - Una desviación estándar de **0.43** cm
#     - El sépalo más ancho menor es de **2.00** cm de ancho
#     - El sépalo más ancho mayor es de **4.40** cm de ancho
#     - Su media es de **3.00** cm de ancho

# %%
df["sepal width"].describe()
# Out:
# count    150.000000
# mean       3.054000
# std        0.433594
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: sepal width, dtype: float64

# %% [markdown]
# ---
# - Para la feature "petal length":
#     - Posee **150** instancias
#     - Tiene un promedio de **3.76** cm de largo
#     - Una desviación estándar de **1.76** cm
#     - El pétalo de largo menor es de **1.00** cm de largo
#     - El pétalo de largo mayor es de **6.90** cm de largo
#     - Su media es de **4.35** cm de largo

# %%
df["petal length"].describe()
# Out:
# count    150.000000
# mean       3.758667
# std        1.764420
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: petal length, dtype: float64

# %% [markdown]
# ---
# - Para la feature "petal width":
#     - Posee **150** instancias
#     - Tiene un promedio de **1.20** cm de ancho
#     - Una desviación estándar de **0.76** cm
#     - El pétalo de ancho menor es de **0.1** cm de ancho
#     - El pétalo de ancho mayor es de **2.5** cm de ancho
#     - Su media es de **1.30** cm de ancho

# %%
df["petal width"].describe()
# Out:
# count    150.000000
# mean       1.198667
# std        0.763161
# min        0.100000
# 25%        0.300000
# 50%        1.300000
# 75%        1.800000
# max        2.500000
# Name: petal width, dtype: float64

# %% [markdown]
# ### d) Cuántas filas existen para cada clase de flor
#     - Existen 50 instancias o filas, para cada clase de flor

# %%
df.groupby("class").count()
# Out:
#                  sepal length  sepal width  petal length  petal width
# class
# Iris-setosa                50           50            50           50
# Iris-versicolor            50           50            50           50
# Iris-virginica             50           50            50           50
